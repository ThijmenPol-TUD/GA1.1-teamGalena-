# %%
def multiply(a,b):
    return a * b

# %%
a = 5
b = 10
result = multiply(a, b)
print(result)

# %%
print(multiply(3, 4))

# %%
print(multiply(8, 4))

# %%
def square(a):
    return multiply(a,a)

# %%
print(square(2))

# %%
print(square(6))

# %%
print(square(10))
